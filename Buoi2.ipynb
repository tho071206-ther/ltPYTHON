# %% [markdown]
# <a href="https://colab.research.google.com/github/tho071206-ther/ltPYTHON/blob/main/Buoi2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# TAO HAM, GOI HAM

def print_hello()
print ("Hello!")

print_hello()
print("1234567")
print_hello()

# DOI SO CUA HAM
## VD1
def my_function(fname, lname):
    print(fname + " " + lname)

my_function("Emil", "Refsnes")


def my_function(food):
    for x in food:
        print(x)

fruits = ["apple", "banana", "cherry"]
my_function(fruits)
## VD2
def print_hello(n):
    print("Hello " * n)

print_hello(3)
print_hello(5)

times = 2
print_hello(times)
